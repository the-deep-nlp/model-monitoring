# %%
import json
import boto3
import pandas as pd

from tqdm import tqdm
from ast import literal_eval
from collections import defaultdict
from postprocess_cpu_model_outputs import convert_current_dict_to_previous_one, get_predictions_all

tqdm.pandas()

# %%
cateogory_names = [
    "sectors", "subpillars_2d", "subpillars_1d", "geo_location", "specific_needs_groups",
    "severity", "age", "gender", "reliability", "affected_groups_level_0",
    "affected_groups_level_1", "affected_groups_level_2", "affected_groups_level_3"
]

# %%
dataset_path = "test_v0.7.1.csv"
df = pd.read_csv(dataset_path)

# %%
def rename_keys(d):
    keys = list(d.keys())
    for k in keys:
        d[f"{k}_pred"] = d.pop(k)
    return d

# %%
class Predictions:
    def __init__(self):
        self.endpoint_name = "main-model-cpu"
        self.sg_client = boto3.session.Session().client(
            "sagemaker-runtime", region_name='us-east-1'
        )

    def create_df(self, entry):
        df = pd.DataFrame({"excerpt": entry, "index": [0]})
        df["return_type"] = "default_analyis"
        df["analyis_framework_id"] = "all"

        df["interpretability"] = False
        df["ratio_interpreted_labels"] = 0.5
        df["return_prediction_labels"] = True

        df["output_backbone_embeddings"] = False
        return df.to_json(orient="split")

    def invoke_endpoint(self, backbone_inputs_json):
        response = self.sg_client.invoke_endpoint(
            EndpointName=self.endpoint_name,
            Body=backbone_inputs_json,
            ContentType="application/json; format=pandas-split"
        )
        response_json = json.loads(response["Body"].read().decode("ascii"))
        return response_json

    def get_predictions(self, excerpt):
        df_json = self.create_df(excerpt)
        predictions = self.invoke_endpoint(df_json)
        return predictions

# %%
predictions = Predictions()

# %%
counts = df["project_id"].value_counts()

# %%
valid_project_ids = counts[counts>1500].index

# %%
valid_project_ids
# Out:
# Float64Index([2028.0, 2170.0, 2098.0], dtype='float64')

# %%
df_new = df[df["project_id"].isin(valid_project_ids)]

# %%
len(df_new)
# Out:
# 6291

# %%
df_new.head()
# Out:
#     entry_id                                            excerpt  \
# 6     187423  [9thNov 2020,Nigeria]With the latest update, N...
# 13    187425  [9thNov 2020,Nigeria]The 94 new cases were rep...
# 19    187426  [5thNov 2020,Nigeria]Abuja, Nigeria’s capital,...
# 40    187463  [10th Nov 2020,NorthEast Nigeria] The North-Ea...
# 51    243576  [January 9, Syria] The areas in northeastern S...
#
#     analysis_framework_id  lead_id  project_id verified               sectors  \
# 6                    1306  43202.0      2170.0    False                    []
# 13                   1306  43202.0      2170.0    False                    []
# 19                   1306  43202.0      2170.0    False                    []
# 40                   1306  43198.0      2170.0    False  ['Shelter', 'Cross']
# 51                   1306  47112.0      2028.0    False            ['Health']
#
#                                         subpillars_2d  \
# 6                                                  []
# 13                                                 []
# 19                                                 []
# 40                       ['Impact->Impact On People']
# 51  ['Priority Interventions->Expressed By Populat...
#
#                                subpillars_1d  \
# 6                        ['Covid-19->Cases']
# 13                       ['Covid-19->Cases']
# 19  ['Covid-19->Cases', 'Covid-19->Testing']
# 40  ['Displacement->Type/Numbers/Movements']
# 51                                        []
#
#                                          geo_location  ...  \
# 6                                         ['Nigeria']  ...
# 13  ['Edo', 'Kwara', 'Federal Capital Territory', ...  ...
# 19                                        ['Nigeria']  ...
# 40            ['Adamawa', 'Nigeria', 'Borno', 'Yobe']  ...
# 51                           ['Syrian Arab Republic']  ...
#
#    affected_groups_level_1 affected_groups_level_2 affected_groups_level_3  \
# 6                       []                      []                      []
# 13                      []                      []                      []
# 19                      []                      []                      []
# 40                      []                      []                      []
# 51                      []                      []                      []
#
#    source_type                                                url  \
# 6      website  https://www.premiumtimesng.com/news/headlines/...
# 13     website  https://www.premiumtimesng.com/news/headlines/...
# 19     website  https://www.premiumtimesng.com/news/headlines/...
# 40     website  https://reliefweb.int/report/nigeria/strengthe...
# 51     website  https://english.enabbaladi.net/archives/2021/0...
#
#                    website lang translation_en  \
# 6   www.premiumtimesng.com   en            NaN
# 13  www.premiumtimesng.com   en            NaN
# 19  www.premiumtimesng.com   en            NaN
# 40       www.reliefweb.int   en            NaN
# 51  english.enabbaladi.net   en            NaN
#
#                                        translation_fr  \
# 6   [9thnov 2020, Nigeria] Avec la dernière mise à...
# 13  [9thnov 2020, Nigeria] Les 94 nouveaux cas ont...
# 19  [5THNOV 2020, Nigeria] Abuja, capitale du Nigé...
# 40  [10 novembre 2020, nord-est du Nigéria] Les Ét...
# 51  [9 janvier, la Syrie] Les régions du nord-est ...
#
#                                        translation_es
# 6   [9thnov 2020, Nigeria] Con la última actualiza...
# 13  [9thnov 2020, Nigeria] Los 94 nuevos casos se ...
# 19  [5thnov 2020, Nigeria] Abuja, la capital de Ni...
# 40  [10 de noviembre de 2020, Northeast Nigeria] L...
# 51  [9 de enero, Siria] Las áreas en el noreste de...
#
# [5 rows x 27 columns]

# %%
sampled_df_per_project = df_new.groupby("project_id").sample(n=50).reset_index(drop=True)

# %%
len(sampled_df_per_project)
# Out:
# 150

# %%
sampled_df_per_project.head(2)
# Out:
#    entry_id                                            excerpt  \
# 0    174380  [6th september,Overall Syria] Riza said there ...
# 1    224488  [December 21, As-Suwayda] Fear of the Coronavi...
#
#    analysis_framework_id  lead_id  project_id verified  \
# 0                   1306  40125.0      2028.0    False
# 1                   1306  46147.0      2028.0    False
#
#                        sectors  \
# 0                   ['Health']
# 1  ['Protection', 'Education']
#
#                                        subpillars_2d         subpillars_1d  \
# 0  ['Humanitarian Conditions->Physical And Mental...  ['Casualties->Dead']
# 1  ['Humanitarian Conditions->Physical And Mental...                    []
#
#                geo_location  ... affected_groups_level_1  \
# 0  ['Syrian Arab Republic']  ...                      []
# 1             ['As-Sweida']  ...                      []
#
#   affected_groups_level_2 affected_groups_level_3 source_type  \
# 0                      []                      []     website
# 1                      []                      []     website
#
#                                                  url                website  \
# 0  https://www.middleeasteye.net/news/coronavirus...  www.middleeasteye.net
# 1                  http://tishreen.news.sy/?p=599768       tishreen.news.sy
#
#   lang translation_en                                     translation_fr  \
# 0   en            NaN  [6 septembre, la Syrie globale] Riza a déclaré...
# 1   en            NaN  [21 décembre, As-Suwayda] La peur du Coronavir...
#
#                                       translation_es
# 0  [6 de septiembre, General Siria] Riza dijo que...
# 1  [21 de diciembre, AS-SUWAYDA] El miedo al Coro...
#
# [2 rows x 27 columns]

# %%
endpoint_outputs = sampled_df_per_project.excerpt.progress_apply(predictions.get_predictions)
# Out:
# 100%|██████████| 150/150 [00:54<00:00,  2.77it/s]

# %%
x = defaultdict(list)

eval_batches = endpoint_outputs.to_list()
for eval_batch in eval_batches:
    output_ratios = eval_batch["raw_predictions"]

    thresholds = eval_batch["thresholds"]

    clean_thresholds = convert_current_dict_to_previous_one(thresholds)

    clean_outputs = [
        convert_current_dict_to_previous_one(one_entry_preds)
        for one_entry_preds in output_ratios
    ]

    final_predictions = get_predictions_all(clean_outputs)
   
    for k, v in final_predictions.items():
        x[k].append(v[0])

# %%
x = rename_keys(x)

# %%
test_df = pd.DataFrame(x)

# %%
merged_df = pd.concat([sampled_df_per_project, test_df], axis=1)

# %%
merged_df
# Out:
#      entry_id                                            excerpt  \
# 0      174380  [6th september,Overall Syria] Riza said there ...
# 1      224488  [December 21, As-Suwayda] Fear of the Coronavi...
# 2      245365  [November 2020, North-west Syria] By November,...
# 3      326857  (Idlib, 03/2021) The Director General of the G...
# 4      164076  Trend analysis and overview: The number of con...
# ..        ...                                                ...
# 145    405617  [9th - 15th Aug 2021, Borno State] Case Manage...
# 146    165963  As of 17 September 2020, the number of confirm...
# 147    172255  [04/10/2020-10/10/2020,Nigeria]According to NC...
# 148    160718  As markets in the neighboring states of Borno,...
# 149    162948  Nearly eight million people were in need of ur...
#
#      analysis_framework_id  lead_id  project_id verified  \
# 0                     1306  40125.0      2028.0    False
# 1                     1306  46147.0      2028.0    False
# 2                     1306  47945.0      2028.0    False
# 3                     1306  51351.0      2028.0    False
# 4                     1306  38063.0      2028.0    False
# ..                     ...      ...         ...      ...
# 145                   1306  63139.0      2170.0    False
# 146                   1306  39937.0      2170.0    False
# 147                   1306  40932.0      2170.0    False
# 148                   1306  39430.0      2170.0    False
# 149                   1306  39230.0      2170.0    False
#
#                                                sectors  \
# 0                                           ['Health']
# 1                          ['Protection', 'Education']
# 2                                                   []
# 3                                             ['WASH']
# 4                                           ['Health']
# ..                                                 ...
# 145                                                 []
# 146                                         ['Health']
# 147                                         ['Health']
# 148  ['Nutrition', 'Cross', 'Food Security', 'Livel...
# 149                                          ['Cross']
#
#                                          subpillars_2d         subpillars_1d  \
# 0    ['Humanitarian Conditions->Physical And Mental...  ['Casualties->Dead']
# 1    ['Humanitarian Conditions->Physical And Mental...                    []
# 2                                                   []   ['Covid-19->Cases']
# 3    ['Impact->Impact On Systems, Services And Netw...                    []
# 4    ['Humanitarian Conditions->Physical And Mental...  ['Casualties->Dead']
# ..                                                 ...                   ...
# 145                                                 []   ['Covid-19->Cases']
# 146  ['Humanitarian Conditions->Physical And Mental...                    []
# 147  ['Humanitarian Conditions->Physical And Mental...                    []
# 148  ['At Risk->Risk And Vulnerabilities', 'Impact-...                    []
# 149  ['Humanitarian Conditions->Number Of People In...                    []
#
#                                        geo_location  ...  \
# 0                          ['Syrian Arab Republic']  ...
# 1                                     ['As-Sweida']  ...
# 2                                     ['Northwest']  ...
# 3                                                []  ...
# 4                          ['Syrian Arab Republic']  ...
# ..                                              ...  ...
# 145                                       ['Borno']  ...
# 146                                     ['Nigeria']  ...
# 147                                     ['Nigeria']  ...
# 148  ['Jigawa', 'Borno', 'Bauchi', 'Gombe', 'Kano']  ...
# 149                                     ['Nigeria']  ...
#
#                                         translation_fr  \
# 0    [6 septembre, la Syrie globale] Riza a déclaré...
# 1    [21 décembre, As-Suwayda] La peur du Coronavir...
# 2    [Novembre 2020, Syrie du Nord-Ouest] En novemb...
# 3    (Idlib, 03/2021) Le directeur général de l'Org...
# 4    Analyse des tendances et aperçu: le nombre de ...
# ..                                                 ...
# 145  [9ème - 15 août 2021, État de Borno] Gestion d...
# 146  Au 17 septembre 2020, le nombre de cas de Covi...
# 147  [04 / 10/2020-10/10/2020, Nigéria] Selon la NC...
# 148  Comme les marchés des États-Unis de Borno, Gom...
# 149  Près de huit millions de personnes ont besoin ...
#
#                                         translation_es  \
# 0    [6 de septiembre, General Siria] Riza dijo que...
# 1    [21 de diciembre, AS-SUWAYDA] El miedo al Coro...
# 2    [De noviembre de 2020, Siria noroeste] Para no...
# 3    (IDLIB, 03/2021) El Director General de la Org...
# 4    Análisis y descripción general de la tendencia...
# ..                                                 ...
# 145  [9º - 15 de agosto 2021, estado BORNO] Gestión...
# 146  A partir del 17 de septiembre de 2020, el núme...
# 147  [04/10 / 2020-10 / 10/2020, Nigeria] Según NCD...
# 148  Como los mercados en los estados vecinos de Bo...
# 149  Cerca de ocho millones de personas necesitaban...
#
#                      sectors_pred  \
# 0                        [Health]
# 1             [Education, Health]
# 2                        [Health]
# 3                          [WASH]
# 4                        [Health]
# ..                            ...
# 145                            []
# 146                      [Health]
# 147                      [Health]
# 148  [Food Security, Livelihoods]
# 149                       [Cross]
#
#                                     subpillars_2d_pred     subpillars_1d_pred  \
# 0    [Humanitarian Conditions->Physical And Mental ...     [Casualties->Dead]
# 1    [Humanitarian Conditions->Living Standards, Im...                     []
# 2    [Humanitarian Conditions->Physical And Mental ...      [Covid-19->Cases]
# 3    [Humanitarian Conditions->Living Standards, Im...                     []
# 4    [Humanitarian Conditions->Physical And Mental ...     [Casualties->Dead]
# ..                                                 ...                    ...
# 145                                                 []      [Covid-19->Cases]
# 146  [Humanitarian Conditions->Physical And Mental ...  [Casualties->Injured]
# 147  [Humanitarian Conditions->Physical And Mental ...                     []
# 148                [At Risk->Risk And Vulnerabilities]                     []
# 149  [Humanitarian Conditions->Number Of People In ...                     []
#
#                                  age_pred gender_pred affected_groups_pred  \
# 0                                      []          []                   []
# 1    [Children/Youth (5 to 17 years old)]          []                   []
# 2                                      []          []                [IDP]
# 3                                      []          []                   []
# 4                                      []          []                   []
# ..                                    ...         ...                  ...
# 145                                    []          []                   []
# 146                                    []          []                   []
# 147                                    []          []                   []
# 148                                    []          []          [Host, IDP]
# 149                                    []          []                   []
#
#     specific_needs_groups_pred severity_pred
# 0                           []    [Critical]
# 1                           []       [Major]
# 2                           []  [Of Concern]
# 3                           []       [Major]
# 4                           []    [Critical]
# ..                         ...           ...
# 145                         []            []
# 146                         []  [Of Concern]
# 147                         []  [Of Concern]
# 148                         []            []
# 149                         []       [Major]
#
# [150 rows x 35 columns]

# %%
for category in cateogory_names:
    merged_df[category] = merged_df[category].apply(literal_eval)

# %%
merged_df
# Out:
#      entry_id                                            excerpt  \
# 0      174380  [6th september,Overall Syria] Riza said there ...
# 1      224488  [December 21, As-Suwayda] Fear of the Coronavi...
# 2      245365  [November 2020, North-west Syria] By November,...
# 3      326857  (Idlib, 03/2021) The Director General of the G...
# 4      164076  Trend analysis and overview: The number of con...
# ..        ...                                                ...
# 145    405617  [9th - 15th Aug 2021, Borno State] Case Manage...
# 146    165963  As of 17 September 2020, the number of confirm...
# 147    172255  [04/10/2020-10/10/2020,Nigeria]According to NC...
# 148    160718  As markets in the neighboring states of Borno,...
# 149    162948  Nearly eight million people were in need of ur...
#
#      analysis_framework_id  lead_id  project_id verified  \
# 0                     1306  40125.0      2028.0    False
# 1                     1306  46147.0      2028.0    False
# 2                     1306  47945.0      2028.0    False
# 3                     1306  51351.0      2028.0    False
# 4                     1306  38063.0      2028.0    False
# ..                     ...      ...         ...      ...
# 145                   1306  63139.0      2170.0    False
# 146                   1306  39937.0      2170.0    False
# 147                   1306  40932.0      2170.0    False
# 148                   1306  39430.0      2170.0    False
# 149                   1306  39230.0      2170.0    False
#
#                                             sectors  \
# 0                                          [Health]
# 1                           [Protection, Education]
# 2                                                []
# 3                                            [WASH]
# 4                                          [Health]
# ..                                              ...
# 145                                              []
# 146                                        [Health]
# 147                                        [Health]
# 148  [Nutrition, Cross, Food Security, Livelihoods]
# 149                                         [Cross]
#
#                                          subpillars_2d       subpillars_1d  \
# 0    [Humanitarian Conditions->Physical And Mental ...  [Casualties->Dead]
# 1    [Humanitarian Conditions->Physical And Mental ...                  []
# 2                                                   []   [Covid-19->Cases]
# 3    [Impact->Impact On Systems, Services And Netwo...                  []
# 4    [Humanitarian Conditions->Physical And Mental ...  [Casualties->Dead]
# ..                                                 ...                 ...
# 145                                                 []   [Covid-19->Cases]
# 146  [Humanitarian Conditions->Physical And Mental ...                  []
# 147  [Humanitarian Conditions->Physical And Mental ...                  []
# 148  [At Risk->Risk And Vulnerabilities, Impact->Im...                  []
# 149  [Humanitarian Conditions->Number Of People In ...                  []
#
#                              geo_location  ...  \
# 0                  [Syrian Arab Republic]  ...
# 1                             [As-Sweida]  ...
# 2                             [Northwest]  ...
# 3                                      []  ...
# 4                  [Syrian Arab Republic]  ...
# ..                                    ...  ...
# 145                               [Borno]  ...
# 146                             [Nigeria]  ...
# 147                             [Nigeria]  ...
# 148  [Jigawa, Borno, Bauchi, Gombe, Kano]  ...
# 149                             [Nigeria]  ...
#
#                                         translation_fr  \
# 0    [6 septembre, la Syrie globale] Riza a déclaré...
# 1    [21 décembre, As-Suwayda] La peur du Coronavir...
# 2    [Novembre 2020, Syrie du Nord-Ouest] En novemb...
# 3    (Idlib, 03/2021) Le directeur général de l'Org...
# 4    Analyse des tendances et aperçu: le nombre de ...
# ..                                                 ...
# 145  [9ème - 15 août 2021, État de Borno] Gestion d...
# 146  Au 17 septembre 2020, le nombre de cas de Covi...
# 147  [04 / 10/2020-10/10/2020, Nigéria] Selon la NC...
# 148  Comme les marchés des États-Unis de Borno, Gom...
# 149  Près de huit millions de personnes ont besoin ...
#
#                                         translation_es  \
# 0    [6 de septiembre, General Siria] Riza dijo que...
# 1    [21 de diciembre, AS-SUWAYDA] El miedo al Coro...
# 2    [De noviembre de 2020, Siria noroeste] Para no...
# 3    (IDLIB, 03/2021) El Director General de la Org...
# 4    Análisis y descripción general de la tendencia...
# ..                                                 ...
# 145  [9º - 15 de agosto 2021, estado BORNO] Gestión...
# 146  A partir del 17 de septiembre de 2020, el núme...
# 147  [04/10 / 2020-10 / 10/2020, Nigeria] Según NCD...
# 148  Como los mercados en los estados vecinos de Bo...
# 149  Cerca de ocho millones de personas necesitaban...
#
#                      sectors_pred  \
# 0                        [Health]
# 1             [Education, Health]
# 2                        [Health]
# 3                          [WASH]
# 4                        [Health]
# ..                            ...
# 145                            []
# 146                      [Health]
# 147                      [Health]
# 148  [Food Security, Livelihoods]
# 149                       [Cross]
#
#                                     subpillars_2d_pred     subpillars_1d_pred  \
# 0    [Humanitarian Conditions->Physical And Mental ...     [Casualties->Dead]
# 1    [Humanitarian Conditions->Living Standards, Im...                     []
# 2    [Humanitarian Conditions->Physical And Mental ...      [Covid-19->Cases]
# 3    [Humanitarian Conditions->Living Standards, Im...                     []
# 4    [Humanitarian Conditions->Physical And Mental ...     [Casualties->Dead]
# ..                                                 ...                    ...
# 145                                                 []      [Covid-19->Cases]
# 146  [Humanitarian Conditions->Physical And Mental ...  [Casualties->Injured]
# 147  [Humanitarian Conditions->Physical And Mental ...                     []
# 148                [At Risk->Risk And Vulnerabilities]                     []
# 149  [Humanitarian Conditions->Number Of People In ...                     []
#
#                                  age_pred gender_pred affected_groups_pred  \
# 0                                      []          []                   []
# 1    [Children/Youth (5 to 17 years old)]          []                   []
# 2                                      []          []                [IDP]
# 3                                      []          []                   []
# 4                                      []          []                   []
# ..                                    ...         ...                  ...
# 145                                    []          []                   []
# 146                                    []          []                   []
# 147                                    []          []                   []
# 148                                    []          []          [Host, IDP]
# 149                                    []          []                   []
#
#     specific_needs_groups_pred severity_pred
# 0                           []    [Critical]
# 1                           []       [Major]
# 2                           []  [Of Concern]
# 3                           []       [Major]
# 4                           []    [Critical]
# ..                         ...           ...
# 145                         []            []
# 146                         []  [Of Concern]
# 147                         []  [Of Concern]
# 148                         []            []
# 149                         []       [Major]
#
# [150 rows x 35 columns]

# %%
merged_df.to_csv("sampled_data_with_predictions_testset.csv", index=False)
